# %% [markdown]
# <a href="https://colab.research.google.com/github/ynes99/fire-detection/blob/main/detection_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/fire
# Out:
# /content/drive/MyDrive/fire

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/fire/yolov5

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-304-g51fb467 Python-3.7.13 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/78.2 GB disk)

# %%
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
#      |████████████████████████████████| 54 kB 3.5 MB/s
#      |████████████████████████████████| 138 kB 68.1 MB/s
#      |████████████████████████████████| 1.1 MB 66.7 MB/s
#      |████████████████████████████████| 4.3 MB 57.0 MB/s
#      |████████████████████████████████| 178 kB 70.8 MB/s
#      |████████████████████████████████| 67 kB 7.2 MB/s
#      |████████████████████████████████| 145 kB 60.8 MB/s
#      |████████████████████████████████| 21.6 MB 87.5 MB/s
#      |████████████████████████████████| 62 kB 1.7 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.11.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
#after following the link above, recieve python code with these fields filled in
#from roboflow import Roboflow
#rf = Roboflow(api_key="YOUR API KEY HERE")
#project = rf.workspace().project("YOUR PROJECT")
#dataset = project.version("YOUR VERSION").download("yolov5")
from roboflow import Roboflow
rf = Roboflow(api_key="p2RzSSbW0COQwEt2RQM5")
project = rf.workspace("bouhelalynes-gmail-com").project("fire-bro")
dataset = project.version(2).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/fire-bro-2 in yolov5pytorch:: 100%|██████████| 2166/2166 [00:01<00:00, 1504.35it/s]

# %%
# !python detect.py --weights /content/drive/MyDrive/fire/yolov5/x/weights/best.pt --img 480 --conf 0.25 --source /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images
# Out:
# detect: weights=['/content/drive/MyDrive/fire/yolov5/x/weights/best.pt'], source=/content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images, data=data/coco128.yaml, imgsz=[480, 480], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-304-g51fb467 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# Model summary: 444 layers, 86173414 parameters, 0 gradients
# image 1/178 /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images/003_rgb_png.rf.943aac4937c9e55a61fb63e6f22931d0.jpg: 320x480 Done. (0.890s)
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/fire/yolov5/l/weights/best.pt --img 480 --conf 0.25 --source /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images
# Out:
# detect: weights=['/content/drive/MyDrive/fire/yolov5/l/weights/best.pt'], source=/content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images, data=data/coco128.yaml, imgsz=[480, 480], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-304-g51fb467 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# Model summary: 367 layers, 46108278 parameters, 0 gradients
# image 1/178 /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images/003_rgb_png.rf.943aac4937c9e55a61fb63e6f22931d0.jpg: 320x480 1 Fire, Done. (0.508s)
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/fire/yolov5/m/weights/best.pt --img 480 --conf 0.25 --source /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images
# Out:
# detect: weights=['/content/drive/MyDrive/fire/yolov5/m/weights/best.pt'], source=/content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images, data=data/coco128.yaml, imgsz=[480, 480], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-304-g51fb467 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# Model summary: 290 layers, 20852934 parameters, 0 gradients
# image 1/178 /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images/003_rgb_png.rf.943aac4937c9e55a61fb63e6f22931d0.jpg: 320x480 2 Fires, Done. (0.297s)
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/fire/yolov5/s/weights/best.pt --img 480 --conf 0.25 --source /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images
# Out:
# detect: weights=['/content/drive/MyDrive/fire/yolov5/s/weights/best.pt'], source=/content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images, data=data/coco128.yaml, imgsz=[480, 480], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-304-g51fb467 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/178 /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images/003_rgb_png.rf.943aac4937c9e55a61fb63e6f22931d0.jpg: 320x480 1 Fire, Done. (0.156s)
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/fire/yolov5/n/weights/best.pt --img 480 --conf 0.25 --source /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images
# Out:
# detect: weights=['/content/drive/MyDrive/fire/yolov5/n/weights/best.pt'], source=/content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images, data=data/coco128.yaml, imgsz=[480, 480], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-304-g51fb467 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# Model summary: 213 layers, 1760518 parameters, 0 gradients
# image 1/178 /content/drive/MyDrive/fire/yolov5/datasets/fire-bro-2/test/images/003_rgb_png.rf.943aac4937c9e55a61fb63e6f22931d0.jpg: 320x480 Done. (0.069s)
# ...
